# %% [markdown]
# # qsn1
# In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# +
# 6

# %%
#mathematicals operator are * , - , +, /

# %%
type('hello')
# Out:
# str

# %%
type(-87.8)
# Out:
# float

# %%
type(6)
# Out:
# int

# %% [markdown]
# # 2
# ///What is the difference between string and variable?
#
#
# ///the string is actually a words, data that is stored in a " ",
# for example........ a = ('hello') ###here a is a variable , which stores the information 'hello' which is in a form of string ###to be specific variable is a name given to refer a value

# %% [markdown]
# # 3. Describe three different data types
# /// integer= 234 ,
# float=12.3
# strings='asd',
# complex= 4+5j
# boolean like and ,or,==,etc

# %% [markdown]
# # 4 What is an expression made up of? What do all expressions do?
# An expression is a combination of values, variables, operators, and calls to functions. Expressions need to be evaluated. If you ask Python to print an expression, the interpreter evaluates the expression and displays the result.

# %% [markdown]
# # 5 This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
# # 6 After running the following code, what does the variable bacon contain?

# %%
bacon = 22
bacon + 1
# Out:
# 23

# %% [markdown]
# # 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3

# %% [markdown]
# # 'spam' + 'spamspam'

# %%
'spam' * 3
# Out:
# 'spamspamspam'

# %% [markdown]
# # 8. Why is eggs a valid variable name while 100 is invalid?

# %% [raw]
# A VARIABLE HAS TO FOLLOW 3 RULES
# 1.It can be only one word.
# 2.It can use only letters, numbers, and the underscore (_) character.
# 3.It can’t begin with a number
#
# SO AS 100 STARTS WITH A NUMBER IT IS INVALID WHILE EGGS IS VALID VARIABLE

# %% [markdown]
# # 9.What three functions can be used to get the integer, floating-point number, or string version of a value?

# %% [raw]
# int(),float(),string()

# %% [markdown]
# # 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'

# %% [markdown]
# 'I have eaten ' + 99 + ' burritos.' by adding '' to 99 and making it a string

# %%
'I have eaten ' + '99' + ' burritos.'
# Out:
# 'I have eaten 99 burritos.'
